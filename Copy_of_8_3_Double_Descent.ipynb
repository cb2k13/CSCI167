# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-ulolrrdx
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-ulolrrdx
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=7e60a3cded4a68b32aaa26138e667b942ae5e19097eca61b2880cb789d24776a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-39wvsdnx/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# I think it will become zero at around 45.
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# I expect the first minima of the double descent curve to appear around 30.
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
# The capacity I expect the maximum of the double descent curve to appear will be around 40.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.298583, train error 88.45,  test loss 2.299153, test error 89.15
# Epoch   100, train loss 1.917763, train error 71.30,  test loss 1.778525, test error 70.40
# Epoch   200, train loss 1.903359, train error 71.35,  test loss 1.754461, test error 70.03
# Epoch   300, train loss 1.907424, train error 73.30,  test loss 1.731614, test error 70.15
# Epoch   400, train loss 1.896205, train error 70.93,  test loss 1.741767, test error 70.15
# Epoch   500, train loss 1.891526, train error 71.18,  test loss 1.740714, test error 68.82
# Epoch   600, train loss 1.893073, train error 70.00,  test loss 1.744640, test error 69.95
# Epoch   700, train loss 1.890773, train error 70.22,  test loss 1.738653, test error 68.28
# Epoch   800, train loss 1.890330, train error 70.93,  test loss 1.723478, test error 69.75
# Epoch   900, train loss 1.889459, train error 70.50,  test loss 1.731817, test error 69.12
# Training model with   4 hidden variables
# Epoch     0, train loss 2.305669, train error 89.55,  test loss 2.307868, test error 90.28
# Epoch   100, train loss 1.854696, train error 68.68,  test loss 1.716797, test error 66.65
# Epoch   200, train loss 1.817043, train error 66.50,  test loss 1.675193, test error 64.28
# Epoch   300, train loss 1.808437, train error 66.32,  test loss 1.665331, test error 65.05
# Epoch   400, train loss 1.805550, train error 66.45,  test loss 1.667928, test error 65.50
# Epoch   500, train loss 1.806939, train error 66.50,  test loss 1.662645, test error 65.43
# Epoch   600, train loss 1.805990, train error 66.22,  test loss 1.661986, test error 66.00
# Epoch   700, train loss 1.802330, train error 66.00,  test loss 1.663617, test error 65.25
# Epoch   800, train loss 1.806720, train error 66.20,  test loss 1.676408, test error 65.40
# Epoch   900, train loss 1.802917, train error 66.10,  test loss 1.670020, test error 66.25
# Training model with   6 hidden variables
# Epoch     0, train loss 2.271201, train error 86.57,  test loss 2.263197, test error 85.85
# Epoch   100, train loss 1.651628, train error 60.58,  test loss 1.468708, test error 56.30
# Epoch   200, train loss 1.625030, train error 58.25,  test loss 1.454163, test error 55.80
# Epoch   300, train loss 1.613005, train error 57.55,  test loss 1.460796, test error 56.88
# Epoch   400, train loss 1.601997, train error 57.75,  test loss 1.442859, test error 56.15
# Epoch   500, train loss 1.595654, train error 57.55,  test loss 1.442942, test error 56.22
# Epoch   600, train loss 1.594022, train error 57.50,  test loss 1.450265, test error 56.65
# Epoch   700, train loss 1.589056, train error 56.72,  test loss 1.449238, test error 56.08
# Epoch   800, train loss 1.588579, train error 56.38,  test loss 1.438293, test error 56.17
# Epoch   900, train loss 1.604729, train error 56.80,  test loss 1.471043, test error 56.90
# Training model with   8 hidden variables
# Epoch     0, train loss 2.174635, train error 80.55,  test loss 2.157524, test error 79.10
# Epoch   100, train loss 1.513630, train error 50.97,  test loss 1.312209, test error 47.42
# Epoch   200, train loss 1.483548, train error 50.35,  test loss 1.277733, test error 46.42
# Epoch   300, train loss 1.461201, train error 49.45,  test loss 1.292002, test error 47.10
# Epoch   400, train loss 1.456018, train error 49.12,  test loss 1.288364, test error 47.05
# Epoch   500, train loss 1.449235, train error 49.38,  test loss 1.287182, test error 47.05
# Epoch   600, train loss 1.444327, train error 49.00,  test loss 1.284915, test error 46.88
# Epoch   700, train loss 1.446696, train error 49.45,  test loss 1.296982, test error 47.42
# Epoch   800, train loss 1.442179, train error 48.38,  test loss 1.296257, test error 47.12
# Epoch   900, train loss 1.437665, train error 48.65,  test loss 1.302187, test error 48.35
# Training model with  10 hidden variables
# Epoch     0, train loss 2.223840, train error 82.72,  test loss 2.207960, test error 83.53
# Epoch   100, train loss 1.540316, train error 52.38,  test loss 1.389330, test error 52.15
# Epoch   200, train loss 1.484611, train error 51.12,  test loss 1.373119, test error 51.92
# Epoch   300, train loss 1.463774, train error 49.78,  test loss 1.386114, test error 51.85
# Epoch   400, train loss 1.455761, train error 49.85,  test loss 1.387082, test error 52.62
# Epoch   500, train loss 1.450274, train error 49.78,  test loss 1.385752, test error 52.30
# Epoch   600, train loss 1.464796, train error 51.42,  test loss 1.402314, test error 52.47
# Epoch   700, train loss 1.447076, train error 50.53,  test loss 1.409011, test error 52.33
# Epoch   800, train loss 1.442794, train error 50.35,  test loss 1.407495, test error 52.33
# Epoch   900, train loss 1.440875, train error 50.28,  test loss 1.401794, test error 52.40
# Training model with  14 hidden variables
# Epoch     0, train loss 2.259821, train error 83.72,  test loss 2.261251, test error 84.20
# Epoch   100, train loss 1.450411, train error 48.75,  test loss 1.358470, test error 50.65
# Epoch   200, train loss 1.375263, train error 47.15,  test loss 1.338455, test error 49.55
# Epoch   300, train loss 1.333161, train error 45.12,  test loss 1.347652, test error 50.05
# Epoch   400, train loss 1.313089, train error 45.35,  test loss 1.361950, test error 50.25
# Epoch   500, train loss 1.294399, train error 44.88,  test loss 1.379107, test error 50.33
# Epoch   600, train loss 1.289046, train error 44.65,  test loss 1.382205, test error 50.05
# Epoch   700, train loss 1.289753, train error 44.30,  test loss 1.385916, test error 49.50
# Epoch   800, train loss 1.290533, train error 45.03,  test loss 1.396389, test error 50.22
# Epoch   900, train loss 1.275298, train error 44.25,  test loss 1.410125, test error 50.45
# Training model with  18 hidden variables
# Epoch     0, train loss 2.231380, train error 84.20,  test loss 2.196095, test error 81.95
# Epoch   100, train loss 1.372139, train error 45.88,  test loss 1.335881, test error 50.20
# Epoch   200, train loss 1.275931, train error 43.22,  test loss 1.367904, test error 51.10
# Epoch   300, train loss 1.238772, train error 43.08,  test loss 1.428569, test error 52.35
# Epoch   400, train loss 1.219392, train error 42.03,  test loss 1.470496, test error 52.55
# Epoch   500, train loss 1.205343, train error 41.88,  test loss 1.512745, test error 53.22
# Epoch   600, train loss 1.198356, train error 41.03,  test loss 1.544171, test error 53.05
# Epoch   700, train loss 1.168959, train error 39.75,  test loss 1.537690, test error 52.53
# Epoch   800, train loss 1.160468, train error 39.40,  test loss 1.573487, test error 52.75
# Epoch   900, train loss 1.155065, train error 39.50,  test loss 1.588717, test error 52.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.179030, train error 82.18,  test loss 2.158852, test error 81.62
# Epoch   100, train loss 1.251595, train error 40.75,  test loss 1.292013, test error 47.58
# Epoch   200, train loss 1.143208, train error 38.38,  test loss 1.381924, test error 48.47
# Epoch   300, train loss 1.081554, train error 36.05,  test loss 1.444322, test error 48.28
# Epoch   400, train loss 1.043572, train error 35.05,  test loss 1.549366, test error 49.85
# Epoch   500, train loss 1.016842, train error 34.35,  test loss 1.607006, test error 51.62
# Epoch   600, train loss 1.009117, train error 33.90,  test loss 1.676500, test error 52.70
# Epoch   700, train loss 0.985682, train error 33.78,  test loss 1.740848, test error 52.25
# Epoch   800, train loss 0.974778, train error 32.80,  test loss 1.764902, test error 52.20
# Epoch   900, train loss 0.965307, train error 33.20,  test loss 1.831173, test error 51.83
# Training model with  26 hidden variables
# Epoch     0, train loss 2.220680, train error 82.05,  test loss 2.200219, test error 81.25
# Epoch   100, train loss 1.183711, train error 39.60,  test loss 1.320573, test error 48.83
# Epoch   200, train loss 1.038003, train error 34.40,  test loss 1.461212, test error 51.22
# Epoch   300, train loss 0.967313, train error 32.07,  test loss 1.582715, test error 51.92
# Epoch   400, train loss 0.918733, train error 30.57,  test loss 1.732809, test error 53.60
# Epoch   500, train loss 0.887832, train error 30.22,  test loss 1.810769, test error 53.65
# Epoch   600, train loss 0.883193, train error 30.10,  test loss 1.919781, test error 55.22
# Epoch   700, train loss 0.848670, train error 28.90,  test loss 1.952754, test error 55.33
# Epoch   800, train loss 0.848499, train error 29.28,  test loss 1.999338, test error 55.58
# Epoch   900, train loss 0.840025, train error 28.32,  test loss 2.051550, test error 55.35
# Training model with  30 hidden variables
# Epoch     0, train loss 2.109495, train error 79.12,  test loss 2.056584, test error 77.68
# Epoch   100, train loss 1.125553, train error 37.10,  test loss 1.341669, test error 48.95
# Epoch   200, train loss 0.949415, train error 31.95,  test loss 1.519548, test error 50.70
# Epoch   300, train loss 0.846500, train error 27.82,  test loss 1.689861, test error 51.08
# Epoch   400, train loss 0.787779, train error 26.70,  test loss 1.880792, test error 52.92
# Epoch   500, train loss 0.756787, train error 25.32,  test loss 2.009173, test error 53.20
# Epoch   600, train loss 0.722397, train error 23.70,  test loss 2.130007, test error 53.62
# Epoch   700, train loss 0.717299, train error 24.90,  test loss 2.266927, test error 54.90
# Epoch   800, train loss 0.680897, train error 22.60,  test loss 2.369267, test error 54.58
# Epoch   900, train loss 0.671643, train error 22.62,  test loss 2.487757, test error 54.65
# Training model with  35 hidden variables
# Epoch     0, train loss 2.150779, train error 78.40,  test loss 2.112102, test error 77.55
# Epoch   100, train loss 1.032909, train error 34.20,  test loss 1.383790, test error 49.28
# Epoch   200, train loss 0.799895, train error 26.07,  test loss 1.646943, test error 51.10
# Epoch   300, train loss 0.675022, train error 22.38,  test loss 2.041861, test error 53.50
# Epoch   400, train loss 0.637051, train error 21.65,  test loss 2.417182, test error 53.17
# Epoch   500, train loss 0.540919, train error 18.20,  test loss 2.815584, test error 55.72
# Epoch   600, train loss 0.557132, train error 19.95,  test loss 3.112020, test error 56.17
# Epoch   700, train loss 0.477838, train error 16.60,  test loss 3.472805, test error 56.35
# Epoch   800, train loss 0.444588, train error 15.82,  test loss 3.846628, test error 56.42
# Epoch   900, train loss 0.500401, train error 18.85,  test loss 4.256629, test error 56.53
# Training model with  40 hidden variables
# Epoch     0, train loss 2.097713, train error 78.90,  test loss 2.048032, test error 77.32
# Epoch   100, train loss 0.900817, train error 29.43,  test loss 1.433423, test error 48.85
# Epoch   200, train loss 0.655046, train error 20.90,  test loss 1.904948, test error 52.08
# Epoch   300, train loss 0.502179, train error 17.03,  test loss 2.508374, test error 53.35
# Epoch   400, train loss 0.381387, train error 12.32,  test loss 3.175503, test error 53.90
# Epoch   500, train loss 0.346973, train error 11.68,  test loss 3.920193, test error 55.12
# Epoch   600, train loss 0.309700, train error 10.15,  test loss 4.638010, test error 55.83
# Epoch   700, train loss 0.289996, train error 9.97,  test loss 5.217260, test error 56.65
# Epoch   800, train loss 0.261735, train error 9.22,  test loss 5.842608, test error 56.65
# Epoch   900, train loss 0.297605, train error 10.28,  test loss 6.393722, test error 57.12
# Training model with  45 hidden variables
# Epoch     0, train loss 2.080681, train error 78.20,  test loss 2.033476, test error 77.60
# Epoch   100, train loss 0.801067, train error 25.03,  test loss 1.481653, test error 49.40
# Epoch   200, train loss 0.482552, train error 14.68,  test loss 2.273817, test error 53.33
# Epoch   300, train loss 0.294433, train error 8.38,  test loss 3.262729, test error 54.78
# Epoch   400, train loss 0.198969, train error 5.47,  test loss 4.469345, test error 55.78
# Epoch   500, train loss 0.156217, train error 4.47,  test loss 5.618924, test error 55.45
# Epoch   600, train loss 0.111464, train error 3.12,  test loss 7.002607, test error 56.47
# Epoch   700, train loss 0.015354, train error 0.00,  test loss 7.958953, test error 55.92
# Epoch   800, train loss 0.009632, train error 0.00,  test loss 8.734497, test error 56.00
# Epoch   900, train loss 0.007030, train error 0.00,  test loss 9.274900, test error 56.00
# Training model with  50 hidden variables
# Epoch     0, train loss 2.129317, train error 78.75,  test loss 2.103814, test error 78.38
# Epoch   100, train loss 0.711387, train error 22.40,  test loss 1.537941, test error 50.15
# Epoch   200, train loss 0.374911, train error 11.22,  test loss 2.569852, test error 52.62
# Epoch   300, train loss 0.168456, train error 4.47,  test loss 3.984287, test error 53.90
# Epoch   400, train loss 0.026371, train error 0.00,  test loss 5.471755, test error 54.72
# Epoch   500, train loss 0.011262, train error 0.00,  test loss 6.353004, test error 54.65
# Epoch   600, train loss 0.007251, train error 0.00,  test loss 6.914451, test error 54.72
# Epoch   700, train loss 0.005260, train error 0.00,  test loss 7.343034, test error 54.90
# Epoch   800, train loss 0.004121, train error 0.00,  test loss 7.678212, test error 54.90
# Epoch   900, train loss 0.003326, train error 0.00,  test loss 7.953947, test error 54.85
# Training model with  55 hidden variables
# Epoch     0, train loss 2.035179, train error 76.05,  test loss 1.980608, test error 75.82
# Epoch   100, train loss 0.585367, train error 17.80,  test loss 1.676286, test error 50.70
# Epoch   200, train loss 0.206469, train error 4.72,  test loss 3.299801, test error 54.65
# Epoch   300, train loss 0.027196, train error 0.00,  test loss 4.953282, test error 55.20
# Epoch   400, train loss 0.012265, train error 0.00,  test loss 5.874736, test error 55.10
# Epoch   500, train loss 0.007405, train error 0.00,  test loss 6.431601, test error 55.42
# Epoch   600, train loss 0.005136, train error 0.00,  test loss 6.853265, test error 55.67
# Epoch   700, train loss 0.003919, train error 0.00,  test loss 7.188430, test error 55.75
# Epoch   800, train loss 0.003127, train error 0.00,  test loss 7.456223, test error 55.75
# Epoch   900, train loss 0.002595, train error 0.00,  test loss 7.683809, test error 55.78
# Training model with  60 hidden variables
# Epoch     0, train loss 2.055433, train error 75.97,  test loss 2.004258, test error 76.53
# Epoch   100, train loss 0.542755, train error 15.62,  test loss 1.835159, test error 52.42
# Epoch   200, train loss 0.125027, train error 1.60,  test loss 3.425712, test error 55.35
# Epoch   300, train loss 0.022779, train error 0.00,  test loss 4.898820, test error 55.35
# Epoch   400, train loss 0.010630, train error 0.00,  test loss 5.690108, test error 55.72
# Epoch   500, train loss 0.006589, train error 0.00,  test loss 6.194717, test error 55.72
# Epoch   600, train loss 0.004685, train error 0.00,  test loss 6.561491, test error 55.65
# Epoch   700, train loss 0.003565, train error 0.00,  test loss 6.853505, test error 55.75
# Epoch   800, train loss 0.002862, train error 0.00,  test loss 7.090013, test error 55.88
# Epoch   900, train loss 0.002376, train error 0.00,  test loss 7.293006, test error 55.75
# Training model with  70 hidden variables
# Epoch     0, train loss 2.020139, train error 75.75,  test loss 1.957026, test error 76.00
# Epoch   100, train loss 0.331958, train error 8.68,  test loss 2.020170, test error 52.10
# Epoch   200, train loss 0.031645, train error 0.00,  test loss 3.708997, test error 53.15
# Epoch   300, train loss 0.010628, train error 0.00,  test loss 4.522226, test error 53.88
# Epoch   400, train loss 0.005986, train error 0.00,  test loss 4.982553, test error 53.90
# Epoch   500, train loss 0.004026, train error 0.00,  test loss 5.298515, test error 53.95
# Epoch   600, train loss 0.002985, train error 0.00,  test loss 5.543746, test error 53.85
# Epoch   700, train loss 0.002344, train error 0.00,  test loss 5.737906, test error 53.80
# Epoch   800, train loss 0.001917, train error 0.00,  test loss 5.901484, test error 53.90
# Epoch   900, train loss 0.001611, train error 0.00,  test loss 6.041375, test error 53.92
# Training model with  80 hidden variables
# Epoch     0, train loss 2.025819, train error 75.32,  test loss 1.940301, test error 74.20
# Epoch   100, train loss 0.236363, train error 4.20,  test loss 2.034008, test error 51.53
# Epoch   200, train loss 0.021887, train error 0.00,  test loss 3.382634, test error 52.92
# Epoch   300, train loss 0.008582, train error 0.00,  test loss 3.950294, test error 53.08
# Epoch   400, train loss 0.004988, train error 0.00,  test loss 4.285812, test error 53.38
# Epoch   500, train loss 0.003422, train error 0.00,  test loss 4.515512, test error 53.30
# Epoch   600, train loss 0.002566, train error 0.00,  test loss 4.694623, test error 53.40
# Epoch   700, train loss 0.002032, train error 0.00,  test loss 4.840814, test error 53.30
# Epoch   800, train loss 0.001669, train error 0.00,  test loss 4.963937, test error 53.30
# Epoch   900, train loss 0.001410, train error 0.00,  test loss 5.067245, test error 53.33
# Training model with  90 hidden variables
# Epoch     0, train loss 2.026720, train error 74.97,  test loss 1.983593, test error 75.05
# Epoch   100, train loss 0.137613, train error 0.72,  test loss 2.238051, test error 52.40
# Epoch   200, train loss 0.015519, train error 0.00,  test loss 3.311599, test error 52.12
# Epoch   300, train loss 0.006799, train error 0.00,  test loss 3.753163, test error 52.05
# Epoch   400, train loss 0.004150, train error 0.00,  test loss 4.023271, test error 52.05
# Epoch   500, train loss 0.002927, train error 0.00,  test loss 4.217476, test error 52.15
# Epoch   600, train loss 0.002224, train error 0.00,  test loss 4.371549, test error 51.92
# Epoch   700, train loss 0.001776, train error 0.00,  test loss 4.496130, test error 52.00
# Epoch   800, train loss 0.001470, train error 0.00,  test loss 4.603563, test error 52.05
# Epoch   900, train loss 0.001247, train error 0.00,  test loss 4.694852, test error 52.20
# Training model with 100 hidden variables
# Epoch     0, train loss 1.973787, train error 72.88,  test loss 1.877390, test error 72.88
# Epoch   100, train loss 0.099854, train error 0.38,  test loss 2.238094, test error 51.15
# Epoch   200, train loss 0.012397, train error 0.00,  test loss 3.077688, test error 51.15
# Epoch   300, train loss 0.005696, train error 0.00,  test loss 3.437872, test error 51.38
# Epoch   400, train loss 0.003543, train error 0.00,  test loss 3.667827, test error 51.35
# Epoch   500, train loss 0.002521, train error 0.00,  test loss 3.833962, test error 51.42
# Epoch   600, train loss 0.001932, train error 0.00,  test loss 3.965299, test error 51.45
# Epoch   700, train loss 0.001554, train error 0.00,  test loss 4.073038, test error 51.33
# Epoch   800, train loss 0.001292, train error 0.00,  test loss 4.164331, test error 51.40
# Epoch   900, train loss 0.001101, train error 0.00,  test loss 4.244336, test error 51.40
# Training model with 120 hidden variables
# Epoch     0, train loss 1.988106, train error 72.53,  test loss 1.928446, test error 73.82
# Epoch   100, train loss 0.048926, train error 0.00,  test loss 2.168274, test error 49.62
# Epoch   200, train loss 0.009446, train error 0.00,  test loss 2.736349, test error 49.62
# Epoch   300, train loss 0.004680, train error 0.00,  test loss 3.002662, test error 49.38
# Epoch   400, train loss 0.002999, train error 0.00,  test loss 3.173677, test error 49.55
# Epoch   500, train loss 0.002165, train error 0.00,  test loss 3.297476, test error 49.53
# Epoch   600, train loss 0.001674, train error 0.00,  test loss 3.398161, test error 49.58
# Epoch   700, train loss 0.001355, train error 0.00,  test loss 3.480429, test error 49.78
# Epoch   800, train loss 0.001132, train error 0.00,  test loss 3.550547, test error 49.72
# Epoch   900, train loss 0.000968, train error 0.00,  test loss 3.611356, test error 49.80
# Training model with 140 hidden variables
# Epoch     0, train loss 1.941936, train error 72.05,  test loss 1.879667, test error 72.85
# Epoch   100, train loss 0.035062, train error 0.00,  test loss 2.194746, test error 50.30
# Epoch   200, train loss 0.007984, train error 0.00,  test loss 2.669778, test error 50.20
# Epoch   300, train loss 0.004129, train error 0.00,  test loss 2.904454, test error 50.28
# Epoch   400, train loss 0.002680, train error 0.00,  test loss 3.055853, test error 50.30
# Epoch   500, train loss 0.001951, train error 0.00,  test loss 3.168366, test error 50.05
# Epoch   600, train loss 0.001517, train error 0.00,  test loss 3.259207, test error 49.92
# Epoch   700, train loss 0.001232, train error 0.00,  test loss 3.334487, test error 49.90
# Epoch   800, train loss 0.001032, train error 0.00,  test loss 3.397491, test error 49.88
# Epoch   900, train loss 0.000884, train error 0.00,  test loss 3.453543, test error 49.90
# Training model with 160 hidden variables
# Epoch     0, train loss 1.952835, train error 71.38,  test loss 1.863916, test error 73.72
# Epoch   100, train loss 0.028444, train error 0.00,  test loss 2.065824, test error 48.30
# Epoch   200, train loss 0.007131, train error 0.00,  test loss 2.463683, test error 48.30
# Epoch   300, train loss 0.003748, train error 0.00,  test loss 2.661784, test error 48.33
# Epoch   400, train loss 0.002465, train error 0.00,  test loss 2.793492, test error 48.55
# Epoch   500, train loss 0.001806, train error 0.00,  test loss 2.890892, test error 48.50
# Epoch   600, train loss 0.001410, train error 0.00,  test loss 2.969832, test error 48.47
# Epoch   700, train loss 0.001148, train error 0.00,  test loss 3.034733, test error 48.47
# Epoch   800, train loss 0.000964, train error 0.00,  test loss 3.090748, test error 48.42
# Epoch   900, train loss 0.000827, train error 0.00,  test loss 3.139108, test error 48.50
# Training model with 180 hidden variables
# Epoch     0, train loss 1.938112, train error 71.03,  test loss 1.875487, test error 73.07
# Epoch   100, train loss 0.024051, train error 0.00,  test loss 2.050143, test error 48.62
# Epoch   200, train loss 0.006575, train error 0.00,  test loss 2.396564, test error 48.75
# Epoch   300, train loss 0.003507, train error 0.00,  test loss 2.571550, test error 48.88
# Epoch   400, train loss 0.002324, train error 0.00,  test loss 2.688181, test error 48.95
# Epoch   500, train loss 0.001710, train error 0.00,  test loss 2.775559, test error 48.95
# Epoch   600, train loss 0.001339, train error 0.00,  test loss 2.844762, test error 49.00
# Epoch   700, train loss 0.001093, train error 0.00,  test loss 2.903652, test error 49.05
# Epoch   800, train loss 0.000920, train error 0.00,  test loss 2.954606, test error 49.03
# Epoch   900, train loss 0.000790, train error 0.00,  test loss 2.998572, test error 49.08
# Training model with 200 hidden variables
# Epoch     0, train loss 1.910744, train error 70.25,  test loss 1.820626, test error 71.18
# Epoch   100, train loss 0.021319, train error 0.00,  test loss 2.028143, test error 48.33
# Epoch   200, train loss 0.006106, train error 0.00,  test loss 2.341210, test error 48.22
# Epoch   300, train loss 0.003327, train error 0.00,  test loss 2.505100, test error 48.12
# Epoch   400, train loss 0.002218, train error 0.00,  test loss 2.613360, test error 48.05
# Epoch   500, train loss 0.001638, train error 0.00,  test loss 2.695739, test error 48.10
# Epoch   600, train loss 0.001287, train error 0.00,  test loss 2.762071, test error 48.15
# Epoch   700, train loss 0.001053, train error 0.00,  test loss 2.816501, test error 48.20
# Epoch   800, train loss 0.000886, train error 0.00,  test loss 2.864396, test error 48.22
# Epoch   900, train loss 0.000763, train error 0.00,  test loss 2.906048, test error 48.17
# Training model with 250 hidden variables
# Epoch     0, train loss 1.865386, train error 68.25,  test loss 1.786615, test error 69.20
# Epoch   100, train loss 0.016988, train error 0.00,  test loss 1.888865, test error 46.45
# Epoch   200, train loss 0.005350, train error 0.00,  test loss 2.140987, test error 46.75
# Epoch   300, train loss 0.002986, train error 0.00,  test loss 2.276009, test error 46.70
# Epoch   400, train loss 0.002018, train error 0.00,  test loss 2.365831, test error 46.72
# Epoch   500, train loss 0.001503, train error 0.00,  test loss 2.435443, test error 46.67
# Epoch   600, train loss 0.001186, train error 0.00,  test loss 2.491547, test error 46.67
# Epoch   700, train loss 0.000974, train error 0.00,  test loss 2.538397, test error 46.65
# Epoch   800, train loss 0.000822, train error 0.00,  test loss 2.579211, test error 46.75
# Epoch   900, train loss 0.000709, train error 0.00,  test loss 2.614936, test error 46.72
# Training model with 300 hidden variables
# Epoch     0, train loss 1.856011, train error 67.93,  test loss 1.778939, test error 69.35
# Epoch   100, train loss 0.014643, train error 0.00,  test loss 1.875052, test error 47.50
# Epoch   200, train loss 0.004857, train error 0.00,  test loss 2.092300, test error 47.40
# Epoch   300, train loss 0.002750, train error 0.00,  test loss 2.210333, test error 47.55
# Epoch   400, train loss 0.001872, train error 0.00,  test loss 2.292443, test error 47.60
# Epoch   500, train loss 0.001400, train error 0.00,  test loss 2.353474, test error 47.53
# Epoch   600, train loss 0.001109, train error 0.00,  test loss 2.403940, test error 47.47
# Epoch   700, train loss 0.000913, train error 0.00,  test loss 2.445776, test error 47.47
# Epoch   800, train loss 0.000772, train error 0.00,  test loss 2.482594, test error 47.47
# Epoch   900, train loss 0.000667, train error 0.00,  test loss 2.514360, test error 47.40
# Training model with 400 hidden variables
# Epoch     0, train loss 1.861383, train error 66.47,  test loss 1.800375, test error 69.07
# Epoch   100, train loss 0.011831, train error 0.00,  test loss 1.825241, test error 46.72
# Epoch   200, train loss 0.004202, train error 0.00,  test loss 2.015918, test error 46.35
# Epoch   300, train loss 0.002432, train error 0.00,  test loss 2.117186, test error 46.22
# Epoch   400, train loss 0.001675, train error 0.00,  test loss 2.189045, test error 46.22
# Epoch   500, train loss 0.001262, train error 0.00,  test loss 2.244280, test error 46.22
# Epoch   600, train loss 0.001005, train error 0.00,  test loss 2.288949, test error 46.25
# Epoch   700, train loss 0.000830, train error 0.00,  test loss 2.326996, test error 46.35
# Epoch   800, train loss 0.000705, train error 0.00,  test loss 2.359410, test error 46.35
# Epoch   900, train loss 0.000611, train error 0.00,  test loss 2.388072, test error 46.38

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
